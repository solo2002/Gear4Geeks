# %% [markdown]
# # Joystick Response
#
# Study parameters of sigmoid function to convert joystick axis to speed

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Logistic function

# %%
def f(a,x):
    return  - 2.0/(1.0 + np.exp(-a*x)) + 1.0

# %%
x1 = np.arange(-255., 255., 1)
plt.plot(x1, f(0.02,x1), 'r')
plt.show()

# %%
def response(a,y):
    val = 1.0 / a * np.log((1 - y)/(1+y))
    return val

# %%
y1 = np.arange(-0.99, 1., 0.01)
plt.plot(y1, response(0.02,y1), 'r')
plt.show()
